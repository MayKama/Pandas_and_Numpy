# %%
import pandas as pd
import numpy as np

# %%
attendance = pd.read_csv('church_attendance.csv')
attendance
# Out:
#     First Name Last Name Worker_Status  House Holde Number  Service attended
# 0       Daniel   Johnson        worker                   5                15
# 1    Blessing       Madu        worker                   3                20
# 2  Makanjuola   Adekunmi        worker                   2                14
# 3        John      James    Non worker                   6                21
# 4     Jeremiah  Akindele        worker                   7                25

# %%
#to clean the columns
column= attendance.columns.to_list()

column[0] = 'First_Name'
column[1]=  'Last_Name'
column[3] = 'House_Hold_Number'
column[4] = 'Service_attended'
column
# Out:
# ['First_Name',
#  'Last_Name',
#  'Worker_Status',
#  'House_Hold_Number',
#  'Service_attended']

# %%
# to assign the changes to the specific colum
attendance.columns = column
attendance
# Out:
#     First_Name Last_Name Worker_Status  House_Hold_Number  Service_attended
# 0       Daniel   Johnson        worker                  5                15
# 1    Blessing       Madu        worker                  3                20
# 2  Makanjuola   Adekunmi        worker                  2                14
# 3        John      James    Non worker                  6                21
# 4     Jeremiah  Akindele        worker                  7                25

# %%
#extracting columns
attendance[['First_Name', 'Last_Name']]
# Out:
#     First_Name Last_Name
# 0       Daniel   Johnson
# 1    Blessing       Madu
# 2  Makanjuola   Adekunmi
# 3        John      James
# 4     Jeremiah  Akindele

# %%
# to add a gender column
gender =['male', 'female','male', 'male','male']

# %%
attendance["Gender"] = gender
attendance
# Out:
#     First_Name Last_Name Worker_Status  House_Hold_Number  Service_attended  \
# 0       Daniel   Johnson        worker                  5                15
# 1    Blessing       Madu        worker                  3                20
# 2  Makanjuola   Adekunmi        worker                  2                14
# 3        John      James    Non worker                  6                21
# 4     Jeremiah  Akindele        worker                  7                25
#
#    Gender
# 0    male
# 1  female
# 2    male
# 3    male
# 4    male

# %%
#edit
#add 4 extra services  to service attended
attendance['Service_attended']= attendance['Service_attended'] +4
attendance
# Out:
#     First_Name Last_Name Worker_Status  House_Hold_Number  Service_attended  \
# 0       Daniel   Johnson        worker                  5                19
# 1    Blessing       Madu        worker                  3                24
# 2  Makanjuola   Adekunmi        worker                  2                18
# 3        John      James    Non worker                  6                25
# 4     Jeremiah  Akindele        worker                  7                29
#
#    Gender
# 0    male
# 1  female
# 2    male
# 3    male
# 4    male

# %%
attendance.sort_values("First_Name")
attendance
# Out:
#     First_Name Last_Name Worker_Status  House_Hold_Number  Service_attended  \
# 0       Daniel   Johnson        worker                  5                19
# 1    Blessing       Madu        worker                  3                24
# 2  Makanjuola   Adekunmi        worker                  2                18
# 3        John      James    Non worker                  6                25
# 4     Jeremiah  Akindele        worker                  7                29
#
#    Gender
# 0    male
# 1  female
# 2    male
# 3    male
# 4    male

# %%
attendance.sort_values(["First_Name", "House_Hold_Number"])
attendance
# Out:
#     First_Name Last_Name Worker_Status  House_Hold_Number  Service_attended  \
# 0       Daniel   Johnson        worker                  5                19
# 1    Blessing       Madu        worker                  3                24
# 2  Makanjuola   Adekunmi        worker                  2                18
# 3        John      James    Non worker                  6                25
# 4     Jeremiah  Akindele        worker                  7                29
#
#    Gender
# 0    male
# 1  female
# 2    male
# 3    male
# 4    male

# %%
attendance.iloc[0]
attendance
# Out:
#     First_Name Last_Name Worker_Status  House_Hold_Number  Service_attended  \
# 0       Daniel   Johnson        worker                  5                19
# 1    Blessing       Madu        worker                  3                24
# 2  Makanjuola   Adekunmi        worker                  2                18
# 3        John      James    Non worker                  6                25
# 4     Jeremiah  Akindele        worker                  7                29
#
#    Gender
# 0    male
# 1  female
# 2    male
# 3    male
# 4    male

# %%
#attendance.pop("Gender")

# %%
#attendance

# %%
attendance.reset_index()
attendance
# Out:
#     First_Name Last_Name Worker_Status  House_Hold_Number  Service_attended  \
# 0       Daniel   Johnson        worker                  5                19
# 1    Blessing       Madu        worker                  3                24
# 2  Makanjuola   Adekunmi        worker                  2                18
# 3        John      James    Non worker                  6                25
# 4     Jeremiah  Akindele        worker                  7                29
#
#    Gender
# 0    male
# 1  female
# 2    male
# 3    male
# 4    male

# %%
attendance = attendance.reset_index()
attendance
# Out:
#    index   First_Name Last_Name Worker_Status  House_Hold_Number  \
# 0      0       Daniel   Johnson        worker                  5
# 1      1    Blessing       Madu        worker                  3
# 2      2  Makanjuola   Adekunmi        worker                  2
# 3      3        John      James    Non worker                  6
# 4      4     Jeremiah  Akindele        worker                  7
#
#    Service_attended  Gender
# 0                19    male
# 1                24  female
# 2                18    male
# 3                25    male
# 4                29    male

# %%
#sorting my column
