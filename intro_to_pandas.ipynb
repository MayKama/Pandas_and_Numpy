# %% [markdown]
# pandas

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
#np.random.seed(123) #is used tomaintain a regular value and remove random generation

# %% [markdown]
# SERIES

# %%
#create a series from: array, list and a dictionary

# %%
mylist = [78, 85,79, 90]
myseries1 = pd.Series(mylist)

# %%
myseries1
# Out:
# 0    78
# 1    85
# 2    79
# 3    90
# dtype: int64

# %%
# to assign index to each of this value: think of it as dictionary

# %%
myind = ['stud_A', 'stud_B','stud_C', 'stud_D']
#to update myseries:

myseries1 = pd.Series(mylist, myind)
myseries1
# Out:
# stud_A    78
# stud_B    85
# stud_C    79
# stud_D    90
# dtype: int64

# %%
#creating series from aarray

# %%
myarr = np.random.randint(0,100, size = (4,))
myarr
# Out:
# array([10,  3, 90, 81])

# %%
myseries2 = pd.Series(myarr)
myseries2
# Out:
# 0    10
# 1     3
# 2    90
# 3    81
# dtype: int32

# %%
#update
myseries2 = pd.Series(myarr, myind)
myseries2
# Out:
# stud_A    10
# stud_B     3
# stud_C    90
# stud_D    81
# dtype: int32

# %%
#dictionary

mydic = {'stud_A': 77, 'stud_B': 98,'stud_C': 67, 'stud_D':88}


myseries3 = pd.Series(mydic)
myseries3
# Out:
# stud_A    77
# stud_B    98
# stud_C    67
# stud_D    88
# dtype: int64

# %% [markdown]
# Basic Operation or Metrix on Series: to check somethings on the series i have created

# %%
myseries3.keys()
# Out:
# Index(['stud_A', 'stud_B', 'stud_C', 'stud_D'], dtype='object')

# %%
myseries2.keys()
# Out:
# Index(['stud_A', 'stud_B', 'stud_C', 'stud_D'], dtype='object')

# %%
myseries1.index
# Out:
# Index(['stud_A', 'stud_B', 'stud_C', 'stud_D'], dtype='object')

# %%
#to combine 2 series together
myseries1 + myseries2
# Out:
# stud_A     88
# stud_B     88
# stud_C    169
# stud_D    171
# dtype: int64

# %%
len(myseries2)
# Out:
# 4

# %%
#to know the minimum and max os our series:we use the aggregate
myseries2.agg(['min','max', 'mean', 'median'])
# Out:
# min        3.0
# max       90.0
# mean      46.0
# median    45.5
# dtype: float64

# %% [markdown]
# help(pd.Series): used to know other functions of series

# %% [markdown]
# DATAFRAME

# %%
#create a dataframe from an array
#to create diff states in Nig and the revenue of each of these states generates
myarr1= np.random.randint(0,100,size = (5,5)) #doing a 2 dimensional array
col = ['River', 'Oyo','Niger','Lagos','Delta']
ind = ['Jan', 'Feb','March','April']
       
df = pd.DataFrame(myarr1)
df
# Out:
#     0   1   2   3   4
# 0  78  21  98  66  35
# 1  70  45  55  85  84
# 2  74  64  15   9  90
# 3  77  52  94  29   6
# 4  37  81  31  52  75

# %%
#to modify the rows with the states


df =pd.DataFrame(myarr1,columns=col,)
df
# Out:
#    River  Oyo  Niger  Lagos  Delta
# 0     78   21     98     66     35
# 1     70   45     55     85     84
# 2     74   64     15      9     90
# 3     77   52     94     29      6
# 4     37   81     31     52     75

# %%
#to modify the column and d rows namd with the month in which the venue was generated
ind = ['Jan', 'Feb','March','April','May']

df =pd.DataFrame(myarr1,index=ind, columns = col)
df
# Out:
#        River  Oyo  Niger  Lagos  Delta
# Jan       78   21     98     66     35
# Feb       70   45     55     85     84
# March     74   64     15      9     90
# April     77   52     94     29      6
# May       37   81     31     52     75

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5 entries, Jan to May
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   River   5 non-null      int32
#  1   Oyo     5 non-null      int32
#  2   Niger   5 non-null      int32
#  3   Lagos   5 non-null      int32
#  4   Delta   5 non-null      int32
# dtypes: int32(5)
# memory usage: 140.0+ bytes

# %%
myarrT = np.random.random((5,5))
myarrT
# Out:
# array([[0.37843098, 0.2865286 , 0.50024776, 0.04139269, 0.22470645],
#        [0.1775137 , 0.05102999, 0.3429047 , 0.57782788, 0.96849162],
#        [0.83357552, 0.0103413 , 0.3887649 , 0.52037056, 0.56858541],
#        [0.53957968, 0.59396261, 0.14099987, 0.32103169, 0.74392074],
#        [0.94521197, 0.31709436, 0.80222736, 0.52035946, 0.32766652]])

# %%
#read my data from a file

mydata = pd.read_csv("autos_mpg.csv")

# %%
mydata
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0        130    3504          12.0
# 1    15.0          8         350.0        165    3693          11.5
# 2    18.0          8         318.0        150    3436          11.0
# 3    16.0          8         304.0        150    3433          12.0
# 4    17.0          8         302.0        140    3449          10.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model_year  origin                   car_name
# 0            70       1  chevrolet chevelle malibu
# ...

# %%
#to have a limited no of rows or columns
mydata.head(10)
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model_year  \
# 0  18.0          8         307.0        130    3504          12.0          70
# 1  15.0          8         350.0        165    3693          11.5          70
# 2  18.0          8         318.0        150    3436          11.0          70
# 3  16.0          8         304.0        150    3433          12.0          70
# 4  17.0          8         302.0        140    3449          10.5          70
# 5  15.0          8         429.0        198    4341          10.0          70
# 6  14.0          8         454.0        220    4354           9.0          70
# 7  14.0          8         440.0        215    4312           8.5          70
# 8  14.0          8         455.0        225    4425          10.0          70
# 9  15.0          8         390.0        190    3850           8.5          70
#
#    origin                   car_name
# 0       1  chevrolet chevelle malibu
# ...

# %%
#to know the information about the columns data
mydata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    398 non-null    object
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   model_year    398 non-null    int64
#  7   origin        398 non-null    int64
#  8   car_name      398 non-null    object
# dtypes: float64(3), int64(4), object(2)
# memory usage: 28.1+ KB

# %%
#to see the end pf the data
mydata.tail()
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model_year  origin         car_name
# 393          82       1  ford mustang gl
# 394          82       2        vw pickup
# 395          82       1    dodge rampage
# 396          82       1      ford ranger
# 397          82       1       chevy s-10

# %%
#to have some statistical information about the data
mydata.describe()
# Out:
#               mpg   cylinders  displacement       weight  acceleration  \
# count  398.000000  398.000000    398.000000   398.000000    398.000000
# mean    23.514573    5.454774    193.425879  2970.424623     15.568090
# std      7.815984    1.701004    104.269838   846.841774      2.757689
# min      9.000000    3.000000     68.000000  1613.000000      8.000000
# 25%     17.500000    4.000000    104.250000  2223.750000     13.825000
# 50%     23.000000    4.000000    148.500000  2803.500000     15.500000
# 75%     29.000000    8.000000    262.000000  3608.000000     17.175000
# max     46.600000    8.000000    455.000000  5140.000000     24.800000
#
#        model_year      origin
# count  398.000000  398.000000
# mean    76.010050    1.572864
# std      3.697627    0.802055
# min     70.000000    1.000000
# 25%     73.000000    1.000000
# 50%     76.000000    1.000000
# 75%     79.000000    2.000000
# max     82.000000    3.000000

# %%
#how to reference a column
mydata["mpg"]
# Out:
# 0      18.0
# 1      15.0
# 2      18.0
# 3      16.0
# 4      17.0
#        ...
# 393    27.0
# 394    44.0
# 395    32.0
# 396    28.0
# 397    31.0
# Name: mpg, Length: 398, dtype: float64

# %%
plt.plot(mydata["mpg"])

# %%
#mydata.save

# %%
mydata['cylinders']
# Out:
# 0      8
# 1      8
# 2      8
# 3      8
# 4      8
#       ..
# 393    4
# 394    4
# 395    4
# 396    4
# 397    4
# Name: cylinders, Length: 398, dtype: int64

# %%
#to work on limited number of column

twodata = mydata[['mpg', 'cylinders']]
twodata
# Out:
#       mpg  cylinders
# 0    18.0          8
# 1    15.0          8
# 2    18.0          8
# 3    16.0          8
# 4    17.0          8
# ..    ...        ...
# 393  27.0          4
# 394  44.0          4
# 395  32.0          4
# 396  28.0          4
# 397  31.0          4
#
# [398 rows x 2 columns]

# %%
#adding a new column, 
mydata['is_overspeed']= False
mydata
#this diplays all the columns that do not have overspeed.
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0        130    3504          12.0
# 1    15.0          8         350.0        165    3693          11.5
# 2    18.0          8         318.0        150    3436          11.0
# 3    16.0          8         304.0        150    3433          12.0
# 4    17.0          8         302.0        140    3449          10.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model_year  origin                   car_name  is_overspeed
# 0            70       1  chevrolet chevelle malibu         False
# ...

# %%
#to drop some columns

mydata.drop(columns="is_overspeed", inplace=True,axis=1)
mydata
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0        130    3504          12.0
# 1    15.0          8         350.0        165    3693          11.5
# 2    18.0          8         318.0        150    3436          11.0
# 3    16.0          8         304.0        150    3433          12.0
# 4    17.0          8         302.0        140    3449          10.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model_year  origin                   car_name
# 0            70       1  chevrolet chevelle malibu
# ...

# %%
#to save my updated file to my folder

mydata.to_csv('autos_mpg_updated.csv')

# %%
#group by meethod to count

mydata.groupby('cylinders').count()
# Out:
#            mpg  displacement  horsepower  weight  acceleration  model_year  \
# cylinders
# 3            4             4           4       4             4           4
# 4          204           204         204     204           204         204
# 5            3             3           3       3             3           3
# 6           84            84          84      84            84          84
# 8          103           103         103     103           103         103
#
#            origin  car_name
# cylinders
# 3               4         4
# 4             204       204
# 5               3         3
# 6              84        84
# 8             103       103
